# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
pip install cartopy geoviews pyproj
# Out:
# Requirement already satisfied: cartopy in c:\users\swaya\anaconda3\lib\site-packages (0.24.1)
# Requirement already satisfied: geoviews in c:\users\swaya\anaconda3\lib\site-packages (1.13.0)
# Requirement already satisfied: pyproj in c:\users\swaya\anaconda3\lib\site-packages (3.7.0)
# Requirement already satisfied: numpy>=1.23 in c:\users\swaya\anaconda3\lib\site-packages (from cartopy) (1.26.4)
# Requirement already satisfied: matplotlib>=3.6 in c:\users\swaya\anaconda3\lib\site-packages (from cartopy) (3.8.4)
# Requirement already satisfied: shapely>=1.8 in c:\users\swaya\anaconda3\lib\site-packages (from cartopy) (2.0.6)
# Requirement already satisfied: packaging>=21 in c:\users\swaya\anaconda3\lib\site-packages (from cartopy) (23.2)
# Requirement already satisfied: pyshp>=2.3 in c:\users\swaya\anaconda3\lib\site-packages (from cartopy) (2.3.1)
# Requirement already satisfied: bokeh<3.6.0,>=3.5.0 in c:\users\swaya\anaconda3\lib\site-packages (from geoviews) (3.5.2)
# Requirement already satisfied: holoviews>=1.16.0 in c:\users\swaya\anaconda3\lib\site-packages (from geoviews) (1.19.0)
# Requirement already satisfied: panel>=1.0.0 in c:\users\swaya\anaconda3\lib\site-packages (from geoviews) (1.5.3)
# Requirement already satisfied: param in c:\users\swaya\anaconda3\lib\site-packages (from geoviews) (2.1.0)
# Requirement already satisfied: xyzservices in c:\users\swaya\anaconda3\lib\site-packages (from geoviews) (2022.9.0)
# Requirement already satisfied: certifi in c:\users\swaya\anaconda3\lib\site-packages (from pyproj) (2024.8.30)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\swaya\anaconda3\lib\site-packages (from bokeh<3.6.0,>=3.5.0->geoviews) (3.1.4)
# Requirement already satisfied: contourpy>=1.2 in c:\users\swaya\anaconda3\lib\site-packages (from bokeh<3.6.0,>=3.5.0->geoviews) (1.2.0)
# Requirement already satisfied: pandas>=1.2 in c:\users\swaya\anaconda3\lib\site-packages (from bokeh<3.6.0,>=3.5.0->geoviews) (2.2.2)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\swaya\anaconda3\lib\site-packages (from bokeh<3.6.0,>=3.5.0->geoviews) (10.3.0)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\swaya\anaconda3\lib\site-packages (from bokeh<3.6.0,>=3.5.0->geoviews) (6.0.1)
# Requirement already satisfied: tornado>=6.2 in c:\users\swaya\anaconda3\lib\site-packages (from bokeh<3.6.0,>=3.5.0->geoviews) (6.4.1)
# Requirement already satisfied: colorcet in c:\users\swaya\anaconda3\lib\site-packages (from holoviews>=1.16.0->geoviews) (3.1.0)
# Requirement already satisfied: pyviz-comms>=2.1 in c:\users\swaya\anaconda3\lib\site-packages (from holoviews>=1.16.0->geoviews) (3.0.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\swaya\anaconda3\lib\site-packages (from matplotlib>=3.6->cartopy) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\swaya\anaconda3\lib\site-packages (from matplotlib>=3.6->cartopy) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\swaya\anaconda3\lib\site-packages (from matplotlib>=3.6->cartopy) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\swaya\anaconda3\lib\site-packages (from matplotlib>=3.6->cartopy) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\swaya\anaconda3\lib\site-packages (from matplotlib>=3.6->cartopy) (2.9.0.post0)
# Requirement already satisfied: bleach in c:\users\swaya\anaconda3\lib\site-packages (from panel>=1.0.0->geoviews) (4.1.0)
# Requirement already satisfied: linkify-it-py in c:\users\swaya\anaconda3\lib\site-packages (from panel>=1.0.0->geoviews) (2.0.0)
# Requirement already satisfied: markdown in c:\users\swaya\anaconda3\lib\site-packages (from panel>=1.0.0->geoviews) (3.4.1)
# Requirement already satisfied: markdown-it-py in c:\users\swaya\anaconda3\lib\site-packages (from panel>=1.0.0->geoviews) (2.2.0)
# Requirement already satisfied: mdit-py-plugins in c:\users\swaya\anaconda3\lib\site-packages (from panel>=1.0.0->geoviews) (0.3.0)
# Requirement already satisfied: requests in c:\users\swaya\anaconda3\lib\site-packages (from panel>=1.0.0->geoviews) (2.32.2)
# Requirement already satisfied: tqdm in c:\users\swaya\anaconda3\lib\site-packages (from panel>=1.0.0->geoviews) (4.66.4)
# Requirement already satisfied: typing-extensions in c:\users\swaya\anaconda3\lib\site-packages (from panel>=1.0.0->geoviews) (4.11.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\swaya\anaconda3\lib\site-packages (from Jinja2>=2.9->bokeh<3.6.0,>=3.5.0->geoviews) (2.1.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\swaya\anaconda3\lib\site-packages (from pandas>=1.2->bokeh<3.6.0,>=3.5.0->geoviews) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\swaya\anaconda3\lib\site-packages (from pandas>=1.2->bokeh<3.6.0,>=3.5.0->geoviews) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\swaya\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.6->cartopy) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\swaya\anaconda3\lib\site-packages (from bleach->panel>=1.0.0->geoviews) (0.5.1)
# Requirement already satisfied: uc-micro-py in c:\users\swaya\anaconda3\lib\site-packages (from linkify-it-py->panel>=1.0.0->geoviews) (1.0.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\swaya\anaconda3\lib\site-packages (from markdown-it-py->panel>=1.0.0->geoviews) (0.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\swaya\anaconda3\lib\site-packages (from requests->panel>=1.0.0->geoviews) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\swaya\anaconda3\lib\site-packages (from requests->panel>=1.0.0->geoviews) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\swaya\anaconda3\lib\site-packages (from requests->panel>=1.0.0->geoviews) (2.2.2)
# Requirement already satisfied: colorama in c:\users\swaya\anaconda3\lib\site-packages (from tqdm->panel>=1.0.0->geoviews) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID           City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0         anadyr  64.7500  177.4833    -10.72        85         100
# 1        1    campo gallo -26.5833  -62.8500     21.39        56           0
# 2        2    yellowknife  62.4560 -114.3525     -4.21        93          75
# 3        3       waitangi -43.9535 -176.5597     13.78        93         100
# 4        4  swift current  50.2834 -107.8014     10.45        62           0
#
#    Wind Speed Country        Date
# 0        5.00      RU  1731118408
# 1        2.65      AR  1731118531
# 2        6.71      CA  1731118532
# 3        8.41      NZ  1731118533
# 4        8.75      CA  1731118534

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot

map_plot = city_data_df.hvplot.points(
    "Lng", 
    "Lat", 
    geo = True, 
    size = "Humidity",
    scale = 1,
    color = "City",
    alpha = 0.5,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500
)

map_plot
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values

narrowed_city_df = city_data_df.loc[
    (city_data_df["Max Temp"] < 27) & (city_data_df["Max Temp"] > 21) \
    & (city_data_df["Wind Speed"] < 4.5) \
    & (city_data_df["Cloudiness"] == 0),:
]

# Drop null values
narrowed_city_df = narrowed_city_df.dropna()

narrowed_city_df
# Out:
#      City_ID             City      Lat       Lng  Max Temp  Humidity  \
# 1          1      campo gallo -26.5833  -62.8500     21.39        56
# 22        22     saint-pierre -21.3393   55.4781     22.82        53
# 32        32         warangal  18.0000   79.5833     21.53        70
# 75        75             tura  25.5198   90.2201     22.27        70
# 83        83         ak'ordat  15.5486   37.8867     26.33        63
# 87        87     san patricio  28.0170  -97.5169     25.97        72
# 92        92   cabo san lucas  22.8909 -109.9124     24.31        60
# 97        97             zuru  11.4241    5.2288     22.35        35
# 105      105           jhansi  25.4333   78.5833     21.32        58
# 157      157          salalah  17.0151   54.0924     25.05        61
# 206      206        tazacorte  28.6290  -17.9293     26.19        30
# 238      238  bandar-e lengeh  26.5579   54.8807     23.06        83
# 288      288           cadale   2.7603   46.3222     26.24        81
# 290      290              sur  22.5667   59.5289     26.78        45
# 304      304             kant  27.8000   79.8000     22.16        57
# 311      311      mitsamiouli -11.3847   43.2844     25.98        78
# 347      347        allapalli  19.4167   80.0667     21.64        75
# 364      364           sittwe  20.1500   92.9000     24.10        70
# 366      366            saham  24.1722   56.8886     25.65        50
# 475      475       sarupathar  26.1984   93.8094     21.13        78
# 487      487          goundam  16.4145   -3.6708     24.44        16
# 499      499          comilla  23.4578   91.2044     22.30        78
# 525      525      gulf breeze  30.3571  -87.1639     25.01        94
# 543      543          sanghar  26.0466   68.9481     24.16        76
# 566      566           howrah  22.5892   88.3103     25.00        83
#
#      Cloudiness  Wind Speed Country        Date
# 1             0        2.65      AR  1731118531
# 22            0        3.60      RE  1731118553
# 32            0        2.23      IN  1731118565
# 75            0        0.92      IN  1731118416
# 83            0        0.36      ER  1731118621
# 87            0        1.30      US  1731118626
# 92            0        2.57      MX  1731118422
# 97            0        4.47      NG  1731118637
# 105           0        2.55      IN  1731118645
# 157           0        1.54      OM  1731118702
# 206           0        4.02      ES  1731118755
# 238           0        0.00      IR  1731118591
# 288           0        3.32      SO  1731118847
# 290           0        1.56      OM  1731118849
# 304           0        1.56      IN  1731118865
# 311           0        1.88      KM  1731118875
# 347           0        0.66      IN  1731118914
# 364           0        3.41      MM  1731118933
# 366           0        0.57      OM  1731118935
# 475           0        0.98      IN  1731119060
# 487           0        4.09      ML  1731119074
# 499           0        2.50      BD  1731119087
# 525           0        1.54      US  1731118858
# 543           0        3.78      PK  1731119136
# 566           0        3.09      IN  1731119162

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity

hotel_df = narrowed_city_df[["City", "Country", "Lat", "Lng", "Humidity"]].copy()

# Add an empty column, "Hotel Name"
hotel_df["Hotel Name"] = ""

# Display sample data
hotel_df
# Out:
#                 City Country      Lat       Lng  Humidity Hotel Name
# 1        campo gallo      AR -26.5833  -62.8500        56
# 22      saint-pierre      RE -21.3393   55.4781        53
# 32          warangal      IN  18.0000   79.5833        70
# 75              tura      IN  25.5198   90.2201        70
# 83          ak'ordat      ER  15.5486   37.8867        63
# 87      san patricio      US  28.0170  -97.5169        72
# 92    cabo san lucas      MX  22.8909 -109.9124        60
# 97              zuru      NG  11.4241    5.2288        35
# 105           jhansi      IN  25.4333   78.5833        58
# 157          salalah      OM  17.0151   54.0924        61
# 206        tazacorte      ES  28.6290  -17.9293        30
# 238  bandar-e lengeh      IR  26.5579   54.8807        83
# 288           cadale      SO   2.7603   46.3222        81
# 290              sur      OM  22.5667   59.5289        45
# 304             kant      IN  27.8000   79.8000        57
# 311      mitsamiouli      KM -11.3847   43.2844        78
# 347        allapalli      IN  19.4167   80.0667        75
# 364           sittwe      MM  20.1500   92.9000        70
# 366            saham      OM  24.1722   56.8886        50
# 475       sarupathar      IN  26.1984   93.8094        78
# 487          goundam      ML  16.4145   -3.6708        16
# 499          comilla      BD  23.4578   91.2044        78
# 525      gulf breeze      US  30.3571  -87.1639        94
# 543          sanghar      PK  26.0466   68.9481        76
# 566           howrah      IN  22.5892   88.3103        83

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel

radius = 10000
params = {
    "categories":"accommodation.hotel",
    "apiKey": geoapify_key,
    "limit":20
}

print("Starting hotel search")


# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    latitude = row["Lat"]
    longitude = row["Lng"]
    

    # Add the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"

    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"

    # Make and API request using the params dictionary
    name_address = requests.get(base_url, params=params)
    print(name_address.status_code)
    

    # Convert the API response to JSON format
    name_address = name_address.json()

    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"

    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# Starting hotel search
# 200
# campo gallo - nearest hotel: Hotel La Plaza
# 200
# saint-pierre - nearest hotel: Tropic Hotel
# 200
# warangal - nearest hotel: city grand
# 200
# tura - nearest hotel: Hotel Polo Orchid
# 200
# ak'ordat - nearest hotel: Omal Hotel
# 200
# san patricio - nearest hotel: No hotel found
# 200
# cabo san lucas - nearest hotel: Comfort Rooms
# 200
# zuru - nearest hotel: No hotel found
# 200
# jhansi - nearest hotel: Jhansi Hotel
# 200
# salalah - nearest hotel: Muscat International Hotel
# 200
# tazacorte - nearest hotel: App Leyma
# 200
# bandar-e lengeh - nearest hotel: Old owner do not like foreigners hotel
# 200
# cadale - nearest hotel: No hotel found
# 200
# sur - nearest hotel: Sur Hotel
# 200
# kant - nearest hotel: No hotel found
# 200
# mitsamiouli - nearest hotel: Hotel le Paradis
# 200
# allapalli - nearest hotel: No hotel found
# 200
# sittwe - nearest hotel: Yuzana Aung Motel 1
# 200
# saham - nearest hotel: No hotel found
# 200
# sarupathar - nearest hotel: No hotel found
# 200
# goundam - nearest hotel: No hotel found
# 200
# comilla - nearest hotel: Hotel Diana
# 200
# gulf breeze - nearest hotel: Holiday Inn Express & Suites Gulf Breeze - Pensacola Area
# 200
# sanghar - nearest hotel: No hotel found
# 200
# howrah - nearest hotel: Sun India Guest House
#                 City Country      Lat       Lng  Humidity  \
# 1        campo gallo      AR -26.5833  -62.8500        56
# 22      saint-pierre      RE -21.3393   55.4781        53
# 32          warangal      IN  18.0000   79.5833        70
# 75              tura      IN  25.5198   90.2201        70
# 83          ak'ordat      ER  15.5486   37.8867        63
# 87      san patricio      US  28.0170  -97.5169        72
# 92    cabo san lucas      MX  22.8909 -109.9124        60
# 97              zuru      NG  11.4241    5.2288        35
# 105           jhansi      IN  25.4333   78.5833        58
# 157          salalah      OM  17.0151   54.0924        61
# 206        tazacorte      ES  28.6290  -17.9293        30
# 238  bandar-e lengeh      IR  26.5579   54.8807        83
# 288           cadale      SO   2.7603   46.3222        81
# 290              sur      OM  22.5667   59.5289        45
# 304             kant      IN  27.8000   79.8000        57
# 311      mitsamiouli      KM -11.3847   43.2844        78
# 347        allapalli      IN  19.4167   80.0667        75
# 364           sittwe      MM  20.1500   92.9000        70
# 366            saham      OM  24.1722   56.8886        50
# 475       sarupathar      IN  26.1984   93.8094        78
# 487          goundam      ML  16.4145   -3.6708        16
# 499          comilla      BD  23.4578   91.2044        78
# 525      gulf breeze      US  30.3571  -87.1639        94
# 543          sanghar      PK  26.0466   68.9481        76
# 566           howrah      IN  22.5892   88.3103        83
#
#                                             Hotel Name
# 1                                       Hotel La Plaza
# 22                                        Tropic Hotel
# 32                                          city grand
# 75                                   Hotel Polo Orchid
# 83                                          Omal Hotel
# 87                                      No hotel found
# 92                                       Comfort Rooms
# 97                                      No hotel found
# 105                                       Jhansi Hotel
# 157                         Muscat International Hotel
# 206                                          App Leyma
# 238             Old owner do not like foreigners hotel
# 288                                     No hotel found
# 290                                          Sur Hotel
# 304                                     No hotel found
# 311                                   Hotel le Paradis
# 347                                     No hotel found
# 364                                Yuzana Aung Motel 1
# 366                                     No hotel found
# 475                                     No hotel found
# 487                                     No hotel found
# 499                                        Hotel Diana
# 525  Holiday Inn Express & Suites Gulf Breeze - Pen...
# 543                                     No hotel found
# 566                              Sun India Guest House

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
map_plot = hotel_df.hvplot.points(
    "Lng", 
    "Lat", 
    geo = True, 
    size = "Humidity",
    scale = 1,
    color = "City",
    alpha = 0.5,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500,
    hover_cols = ["Hotel Name", "Country"]
)

map_plot
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)
